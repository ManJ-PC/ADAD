# %% [markdown]
# <a href="https://colab.research.google.com/github/Camolas/ADAD/blob/master/Experi%C3%AAncias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#! pip install pandas
#! conda env list
#df = pd.read_csv("ComaSessions.csv")
#df.head()

# %%
url = 'https://raw.githubusercontent.com/Camolas/ML_DOC/master/Databases/SmartAvaliationPrototype.csv'

# %%
from numpy import genfromtxt
my_data = genfromtxt('https://raw.githubusercontent.com/Camolas/ML_DOC/master/Databases/SmartAvaliationPrototype.csv', delimiter=',')

# %%
docDF = pd.read_csv(url)

# %%
type(docDF)
# Out:
# pandas.core.frame.DataFrame

# %%
docDF.head()
# Out:
#    Order  ID  ...  BothRatersSession10  BothRatersCertainty10
# 0      1   1  ...                    2                    100
# 1      2   2  ...                    2                    100
# 2      3   3  ...                    2                    100
# 3      4   4  ...                    1                     80
# 4      5   5  ...                    2                    100
#
# [5 rows x 148 columns]

# %%
print(my_data)
# Out:
# [[ nan  nan  nan ...  nan  nan  nan]
#  [  1.   1.   1. ... 100.   2. 100.]
#  [  2.   2.   2. ... 100.   2. 100.]
#  ...
#  [ 33.  50.   2. ... 100.   2. 100.]
#  [ 34.  51.   2. ... 100.   2. 100.]
#  [ 35.  52.   2. ... 100.   2. 100.]]

# %%
docDF.describe()
# Out:
#            Order         ID  ...  BothRatersSession10  BothRatersCertainty10
# count  35.000000  35.000000  ...            35.000000              35.000000
# mean   18.000000  29.000000  ...             1.685714              98.571429
# std    10.246951  16.615018  ...             0.471008               4.936572
# min     1.000000   1.000000  ...             1.000000              80.000000
# 25%     9.500000  14.000000  ...             1.000000             100.000000
# 50%    18.000000  33.000000  ...             2.000000             100.000000
# 75%    26.500000  42.500000  ...             2.000000             100.000000
# max    35.000000  52.000000  ...             2.000000             100.000000
#
# [8 rows x 132 columns]

# %% [markdown]
# # Machine Learning

# %%
docDF['Diagnostic'].value_counts()
# Out:
# 2    25
# 1    10
# Name: Diagnostic, dtype: int64

# %%
docDF
# Out:
#     Order  ID  ...  BothRatersSession10  BothRatersCertainty10
# 0       1   1  ...                    2                    100
# 1       2   2  ...                    2                    100
# 2       3   3  ...                    2                    100
# 3       4   4  ...                    1                     80
# 4       5   5  ...                    2                    100
# 5       6   6  ...                    2                    100
# 6       7   7  ...                    1                    100
# 7       8   8  ...                    2                    100
# 8       9   9  ...                    1                    100
# 9      10  19  ...                    2                     90
# 10     11  22  ...                    2                    100
# 11     12  23  ...                    2                    100
# 12     13  25  ...                    2                    100
# 13     14  26  ...                    2                    100
# ...

# %%
docDF.isnull().sum() #Missing values flagged by NA
# Out:
# Order                    0
# ID                       0
# Sex                      0
# Age                      0
# Etiology                 0
#                         ..
# BothRatersCertainty8     0
# BothRatersSession9       0
# BothRatersCertainty9     0
# BothRatersSession10      0
# BothRatersCertainty10    0
# Length: 148, dtype: int64
